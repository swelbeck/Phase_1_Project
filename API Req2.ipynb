# %%
import pandas as pd
import numpy as np
import requests
import json
#from yelp.client import Client
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
url = 'https://api.themoviedb.org/3/discover/movie?api_key=a033e140831df183efc1df7cc9e60d21&movie?&sort_by=revenue.desc&primary_release_year=2010-2020'
response = requests.get(url)
# /discover/movie?with_genres=35&with_cast=23659&sort_by=revenue.desc

# %%
response.status_code
# Out:
# 200

# %%
MY_API_KEY = "a033e140831df183efc1df7cc9e60d21"
MY_API_ACCESS_TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhMDMzZTE0MDgzMWRmMTgzZWZjMWRmN2NjOWU2MGQyMSIsInN1YiI6IjVmYTVjZDFlMjE2MjFkMDA0MGY1MGQ4MSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k7wJbIIivZPK0CbpqG5VYXxJ8cZ8bg1HppwH7injreE"

term = 'movie'
sort_by = 'popularity'
SEARCH_LIMIT = None

url = 'https://api.themoviedb.org/3/discover/movie?api_key=a033e140831df183efc1df7cc9e60d21&movie?&sort_by=revenue.desc&primary_release_year=2010-2020&'

#opional parameter in get reqest that allows us to use our api key
headers = {
        'Authorization': 'Bearer {}'.format(MY_API_ACCESS_TOKEN),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'sort_by': sort_by.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
json.loads(response.text)
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 0.6,
#    'id': 354394,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Doctor Who: Seasons of War',
#    'release_date': '2015-01-30',
#    'original_language': 'en',
#    'original_title': 'Doctor Who: Seasons of War',
#    'genre_ids': [878],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': "'Seasons of War' is an unofficial short film that features the character of the War Doctor from the BBC TV series Doctor Who. It was created to help promote an anthology of specially-commissioned stories about him - all in aid of the UK charity, Caudwell Children.",
#    'poster_path': None},
#   {'popularity': 1.716,
#    'id': 743835,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': "Halloween: The Curse of Michael Myers (The Producer's Cut)",
#    'release_date': '2013-10-27',
#    'original_language': 'en',
# ...
