# %%
# !pip install rotten_tomatoes_cli

# %%
from rotten_tomatoes_client import RottenTomatoesClient

# %%
from rotten_tomatoes_client import RottenTomatoesClient, MovieBrowsingQuery, Service, Genre, SortBy, MovieBrowsingCategory

# Give me some relatively shitty action, comedy, or romance movies on Netflix or Amazon Prime, sorted by popularity
query = MovieBrowsingQuery(minimum_rating=60, maximum_rating=100, certified_fresh = True,
                           sort_by=SortBy.popularity)

result = RottenTomatoesClient.browse_movies(query=query)

# %%
result
# Out:
# {'counts': {'total': 12, 'count': 12},
#  'results': [{'id': 771508379,
#    'title': 'The Climb',
#    'url': '/m/the_climb_2020',
#    'tomatoIcon': 'certified_fresh',
#    'tomatoScore': 94,
#    'theaterReleaseDate': 'Nov 13',
#    'mpaaRating': 'R',
#    'synopsis': '<em>The Climb</em> uses the complicated bond between two friends to dissect male friendships in engaging -- and frequently funny -- fashion.',
#    'synopsisType': 'consensus',
#    'runtime': '1 hr. 34 min.',
#    'posters': {'thumborId': 'v1.bTsxMzMyNzc4MTtqOzE4NjQ5OzEyMDA7NjQ4Ozk2MA',
#     'primary': 'https://resizing.flixster.com/MajCkbVSGYyjYTAmZJNNH-_jcyk=/130x0/v1.bTsxMzMyNzc4MTtqOzE4NjQ5OzEyMDA7NjQ4Ozk2MA'},
#    'actors': ['Kyle Marvin', 'Michael Angelo Covino', 'Gayle Rankin']},
#   {'id': 771522583,
#    'title': 'Wolfwalkers',
#    'url': '/m/wolfwalkers',
#    'tomatoIcon': 'certified_fresh',
#    'tomatoScore': 97,
#    'theaterReleaseDate': 'Nov 13',
#    'dvdReleaseDate': 'Dec 11',
# ...
