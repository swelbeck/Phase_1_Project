# %% [markdown]
# # API Requests

# %%
import pandas as pd
import numpy as np
import requests
import json
#from yelp.client import Client
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
url = 'https://api.themoviedb.org/3/movie/76341?api_key=a033e140831df183efc1df7cc9e60d21&movie?sort_by=popularity.desc'
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
print(response)
# Out:
# <Response [200]>

# %%
MY_API_KEY = "a033e140831df183efc1df7cc9e60d21"
MY_API_ACCESS_TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhMDMzZTE0MDgzMWRmMTgzZWZjMWRmN2NjOWU2MGQyMSIsInN1YiI6IjVmYTVjZDFlMjE2MjFkMDA0MGY1MGQ4MSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k7wJbIIivZPK0CbpqG5VYXxJ8cZ8bg1HppwH7injreE"

term = 'movie'
sort_by = 'popularity'
SEARCH_LIMIT = None

url = 'https://api.themoviedb.org/3/discover/movie?api_key=a033e140831df183efc1df7cc9e60d21&language=en-US&sort_by=popularity.desc&primary_release_year=2010-2020'

#opional parameter in get reqest that allows us to use our api key
headers = {
        'Authorization': 'Bearer {}'.format(MY_API_ACCESS_TOKEN),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'sort_by': sort_by.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
response.status_code
# Out:
# 200

# %%
json.loads(response.text)
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 1.4,
#    'id': 748506,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Untitled A24 Ronnie Spector Biopic/ Be My Baby',
#    'release_date': '',
#    'original_language': 'en',
#    'original_title': 'Untitled A24 Ronnie Spector Biopic/ Be My Baby',
#    'genre_ids': [10402, 18],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'The biopic will place emphasis on Spector’s early career, particularly on the formation of the Ronettes group and their subsequent signing to Phil Spector’s Philles Records. While at the label, the band recorded their hit “Be My Baby,” and Spector eventually married the record producer. The film will also follow their eventual divorce and Spector’s battle to gain back the rights to her music.  Spector\'s "Be My Baby" serves as inspiration for the film.',
#    'poster_path': None},
#   {'popularity': 0.6,
#    'id': 703250,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'The Switch',
#    'release_date': '',
#    'original_language': 'en',
#    'original_title': 'The Switch',
#    'genre_ids': [],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'A  29-year-old consultant, and her 79-year-old grandmother, who decide to swap lives (including cell phones) for two months, after a series of personal setbacks. While the younger woman moves to a tiny Yorkshire village to tackle the responsibilities of dog walking and neighborhood watch, the older woman finds herself in a tiny London flat, navigating dating apps and starting up a social club for lonely Londoners.',
#    'poster_path': '/lzWtlChjdE4iPuIPmklUbybWROc.jpg'},
#   {'popularity': 1.085,
#    'id': 277737,
#    'video': False,
#    'vote_count': 4,
#    'vote_average': 5,
#    'title': "Smosh's If It Were Real Saga",
#    'release_date': '2013-01-01',
#    'original_language': 'en',
#    'original_title': "Smosh's If It Were Real Saga",
#    'genre_ids': [35],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'SMOSH\'S IF IT WERE REAL SAGA follows Ian and Anthony (SMOSH) as they try to make it to a clip show of their classic "If_Were Real" videos.',
#    'poster_path': '/r7J6QPAZlNK8TWOO2OrG9hbKPMl.jpg'},
#   {'popularity': 0,
#    'id': 643102,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Diary of an E-Celeb',
#    'release_date': '2019-07-19',
#    'original_language': 'en',
#    'original_title': 'Diary of an E-Celeb',
#    'genre_ids': [35, 99],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': "A documentary which showcases the lengths E-Celebrities go to in order to maintain their fleeting relevance, namely by following the disturbing tale of one of the internet's most desperate subjects, Baked Alaska",
#    'poster_path': '/dYAhTPYDyKqpBKKPBRINxTuXx4B.jpg'},
#   {'popularity': 0.6,
#    'id': 634153,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Blacklisted',
#    'release_date': '2018-10-29',
#    'original_language': 'en',
#    'original_title': 'Blacklisted',
#    'genre_ids': [35, 99],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'Documentary following Million Dollar Extreme after the cancellation of their Adult Swim television series, World Peace.',
#    'poster_path': '/rRqFRELygzz4J4kkGhCUG7mAOzb.jpg'},
#   {'popularity': 0,
#    'vote_count': 0,
#    'video': False,
#    'poster_path': '/7FPsAoB7P239O7BuMjhlb7QzfBs.jpg',
#    'id': 643130,
#    'adult': False,
#    'backdrop_path': None,
#    'original_language': 'en',
#    'original_title': 'An Inconvenient Goof',
#    'genre_ids': [35, 99],
#    'title': 'An Inconvenient Goof',
#    'vote_average': 0,
#    'overview': "A documentary chronicling the career of stand-up comedian, Joe Matarese, who was eliminated during season 9 of America's Got Talrent.",
#    'release_date': '2018-08-10'},
#   {'popularity': 0,
#    'id': 641183,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': "Heights or A Bisexual Woman's Existential Musings on Los Angeles",
#    'release_date': '2016-08-20',
#    'original_language': 'en',
#    'original_title': "Heights or A Bisexual Woman's Existential Musings on Los Angeles",
#    'genre_ids': [],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'A lonely woman living in Los Angeles displays an inability to reconcile her nefarious and fruitless past -- of a failed same sex relationship -- with her present, causing her to continually seek an escape from life, from the now, while simultaneously trying to embrace it. The futile tensions of these two elements, which include an aspect of privacy versus communication, affect her daily existence.',
#    'poster_path': '/mXRTrXf4Pd4CZB2v4zw7U0dLTyB.jpg'},
#   {'popularity': 0.6,
#    'vote_count': 1,
#    'video': False,
#    'poster_path': '/h7RNzvmNeavlcuo6hnYpS2eKN38.jpg',
#    'id': 593425,
#    'adult': False,
#    'backdrop_path': None,
#    'original_language': 'en',
#    'original_title': 'Killer in a Red Dress',
#    'genre_ids': [53],
#    'title': 'Killer in a Red Dress',
#    'vote_average': 5,
#    'overview': "Christa Bright is an aspiring personal stylist who has an instant connection with new client Kat Niven, a shy woman who needs help gaining confidence. But when Kat's admiration for Christa turns into plain obsession, Christa begins to get suspicious. She soon discovers that Kat is her fiance Jack's ex-girlfriend and she's trying to become Christa in a demented ploy to win Jack back for good.",
#    'release_date': '2018-12-01'},
#   {'popularity': 0.6,
#    'vote_count': 0,
#    'video': False,
#    'poster_path': None,
#    'id': 636442,
#    'adult': False,
#    'backdrop_path': None,
#    'original_language': 'en',
#    'original_title': 'Into the Dark Collection',
#    'genre_ids': [],
#    'title': 'Into the Dark Collection',
#    'vote_average': 0,
#    'overview': 'Into the Dark is an anthology series, where the theme of each episode of the series is inspired by a holiday from the month in which it is released',
#    'release_date': ''},
#   {'popularity': 0,
#    'id': 643153,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Alpha Brain',
#    'release_date': '2019-03-22',
#    'original_language': 'en',
#    'original_title': 'Alpha Brain',
#    'genre_ids': [35, 99],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': "Joe Rogan went from stand-up comedian, to actor, to reality TV host, to the world's most popular podcast host. This is the story of an icon.",
#    'poster_path': '/bDlDnHzNZRF3wbd1xWjK9in1kKb.jpg'},
#   {'popularity': 0,
#    'id': 643160,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'The Sargonian Effect',
#    'release_date': '2019-05-12',
#    'original_language': 'en',
#    'original_title': 'The Sargonian Effect',
#    'genre_ids': [35, 99],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'Carl Benjamin a.k.a. Sargon of Akkad was arguably the biggest name in the anti-SJW sphere on the internet, but once he decided to actually debate people, viewers started to see him for what he truly is.',
#    'poster_path': '/9Cf2XbtqIjElVZfJ7h6PCoemBL1.jpg'},
#   {'popularity': 0.6,
#    'id': 578939,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'The Covington Kids True Story',
#    'release_date': '2019-01-25',
#    'original_language': 'en',
#    'original_title': 'The Covington Kids True Story',
#    'genre_ids': [99],
#    'backdrop_path': '/qk8HEHBbKW6eHQ5NrVlFpiaoi4n.jpg',
#    'adult': False,
#    'overview': 'Infowars host, Alex Jones teams up with lawyer, Robert Barnes to expose the lies & manipulation from the mainstream media regarding the Covington Catholic School controversy which kicked off 2019.',
#    'poster_path': '/umCrW7gmsk4rfMB3H0MZTAuqtQd.jpg'},
#   {'popularity': 0,
#    'id': 650027,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Nova',
#    'release_date': '',
#    'original_language': 'en',
#    'original_title': 'Nova',
#    'genre_ids': [28, 878],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'Upcoming Marvel Studios project confirmed to be in development.',
#    'poster_path': None},
#   {'popularity': 0,
#    'id': 654744,
#    'video': False,
#    'vote_count': 0,
#    'vote_average': 0,
#    'title': 'Charlottesville: The True Alt-Right',
#    'release_date': '2018-04-02',
#    'original_language': 'en',
#    'original_title': 'Charlottesville: The True Alt-Right',
#    'genre_ids': [99],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'A found-footage documentary recapping the events of (and analyzing the rhetoric around) the 2017 "Unite the Right" rally, organized and attended by neo-Nazis such as David Duke and Richard Spenser.',
#    'poster_path': '/tL69IeY8nHGHHYmfARvTHEQzEZf.jpg'},
#   {'popularity': 0,
#    'vote_count': 0,
#    'video': False,
#    'poster_path': '/o9uzzJtVRzr6IcpTJ5bDVms9WCC.jpg',
#    'id': 654266,
#    'adult': False,
#    'backdrop_path': None,
#    'original_language': 'en',
#    'original_title': 'Dirty Talk',
#    'genre_ids': [],
#    'title': 'Dirty Talk',
#    'vote_average': 0,
#    'overview': 'Nathan, a conservative English teacher, tells his best friend Zach about a one-night stand with a hot Latin man who loves to talk dirty in this short comedy.',
#    'release_date': '2013-10-16'}]}

# %%
movie_pop = response.text
movie_pop = json.loads(movie_pop)

# %%
MY_API_KEY = "a033e140831df183efc1df7cc9e60d21"
MY_API_ACCESS_TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhMDMzZTE0MDgzMWRmMTgzZWZjMWRmN2NjOWU2MGQyMSIsInN1YiI6IjVmYTVjZDFlMjE2MjFkMDA0MGY1MGQ4MSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k7wJbIIivZPK0CbpqG5VYXxJ8cZ8bg1HppwH7injreE"

term = 'movie'
sort_by = 'popularity'
SEARCH_LIMIT = None

url = 'https://api.themoviedb.org/3/trending/movie/week?api_key=a033e140831df183efc1df7cc9e60d21&sort_by=popularity.desc&primary_release_year=2020'

#opional parameter in get reqest that allows us to use our api key
headers = {
        'Authorization': 'Bearer {}'.format(MY_API_ACCESS_TOKEN),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'sort_by': sort_by.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
resp = requests.get(url, headers=headers, params=url_params)

# %%
resp.status_code
# Out:
# 200

# %%
json.loads(resp.text)
# Out:
# {'page': 1,
#  'results': [{'id': 400160,
#    'video': False,
#    'vote_count': 1046,
#    'vote_average': 8.3,
#    'title': 'The SpongeBob Movie: Sponge on the Run',
#    'release_date': '2020-08-14',
#    'original_language': 'en',
#    'original_title': 'The SpongeBob Movie: Sponge on the Run',
#    'genre_ids': [14, 16, 12, 35, 10751],
#    'backdrop_path': '/wu1uilmhM4TdluKi2ytfz8gidHf.jpg',
#    'adult': False,
#    'overview': 'When his best friend Gary is suddenly snatched away, SpongeBob takes Patrick on a madcap mission far beyond Bikini Bottom to save their pink-shelled pal.',
#    'poster_path': '/jlJ8nDhMhCYJuzOw3f52CP1W8MW.jpg',
#    'popularity': 1114.882,
#    'media_type': 'movie'},
#   {'id': 531219,
#    'video': False,
#    'vote_count': 590,
#    'vote_average': 7.1,
#    'title': "Roald Dahl's The Witches",
#    'release_date': '2020-10-26',
#    'original_language': 'en',
#    'original_title': "Roald Dahl's The Witches",
#    'genre_ids': [14, 10751, 12, 35, 27],
#    'backdrop_path': '/8rIoyM6zYXJNjzGseT3MRusMPWl.jpg',
#    'adult': False,
#    'overview': "In late 1967, a young orphaned boy goes to live with his loving grandma in the rural Alabama town of Demopolis. As the boy and his grandmother encounter some deceptively glamorous but thoroughly diabolical witches, she wisely whisks him away to a seaside resort. Regrettably, they arrive at precisely the same time that the world's Grand High Witch has gathered.",
#    'poster_path': '/betExZlgK0l7CZ9CsCBVcwO1OjL.jpg',
#    'popularity': 2007.928,
#    'media_type': 'movie'},
#   {'id': 340102,
#    'video': False,
#    'vote_count': 515,
#    'vote_average': 6.2,
#    'title': 'The New Mutants',
#    'release_date': '2020-08-26',
#    'original_language': 'en',
#    'original_title': 'The New Mutants',
#    'genre_ids': [28, 878, 27, 12],
#    'backdrop_path': '/eCIvqa3QVCx6H09bdeOS8Al2Sqy.jpg',
#    'adult': False,
#    'overview': 'Five young mutants, just discovering their abilities while held in a secret facility against their will, fight to escape their past sins and save themselves.',
#    'poster_path': '/xrI4EnZWftpo1B7tTvlMUXVOikd.jpg',
#    'popularity': 480.274,
#    'media_type': 'movie'},
#   {'id': 740985,
#    'video': False,
#    'vote_count': 789,
#    'vote_average': 6.7,
#    'title': 'Borat Subsequent Moviefilm',
#    'release_date': '2020-10-23',
#    'original_language': 'en',
#    'original_title': 'Borat Subsequent Moviefilm',
#    'genre_ids': [35],
#    'backdrop_path': '/hbrXbVoE0NuA1ORoSGGYNASagrl.jpg',
#    'adult': False,
#    'overview': '14 years after making a film about his journey across the USA, Borat risks life and limb when he returns to the United States with his young daughter, and reveals more about the culture, the COVID-19 pandemic, and the political elections.',
#    'poster_path': '/6agKYU5IQFpuDyUYPu39w7UCRrJ.jpg',
#    'popularity': 806.945,
#    'media_type': 'movie'},
#   {'id': 337401,
#    'video': False,
#    'vote_count': 2807,
#    'vote_average': 7.2,
#    'title': 'Mulan',
#    'release_date': '2020-09-04',
#    'original_language': 'en',
#    'original_title': 'Mulan',
#    'genre_ids': [28, 12, 18, 14],
#    'backdrop_path': '/zzWGRw277MNoCs3zhyG3YmYQsXv.jpg',
#    'adult': False,
#    'overview': 'When the Emperor of China issues a decree that one man per family must serve in the Imperial Chinese Army to defend the country from Huns, Hua Mulan, the eldest daughter of an honored warrior, steps in to take the place of her ailing father. She is spirited, determined and quick on her feet. Disguised as a man by the name of Hua Jun, she is tested every step of the way and must harness her innermost strength and embrace her true potential.',
#    'poster_path': '/aKx1ARwG55zZ0GpRvU2WrGrCG9o.jpg',
#    'popularity': 752.021,
#    'media_type': 'movie'},
#   {'id': 615665,
#    'video': False,
#    'vote_count': 529,
#    'vote_average': 7.3,
#    'title': 'Holidate',
#    'release_date': '2020-10-28',
#    'original_language': 'en',
#    'original_title': 'Holidate',
#    'genre_ids': [35, 10749],
#    'backdrop_path': '/dUN960snyYJv3UfCOUEW071Ww7w.jpg',
#    'adult': False,
#    'overview': "Fed up with being single on holidays, two strangers agree to be each other's platonic plus-ones all year long, only to catch real feelings along the way.",
#    'poster_path': '/lAaJc9842RDVrjvR3OLPMTeHkiA.jpg',
#    'popularity': 406.635,
#    'media_type': 'movie'},
#   {'adult': False,
#    'backdrop_path': '/gvEAq0gaEqWZ2ifPW7j8jGwF69M.jpg',
#    'genre_ids': [28, 53],
#    'id': 625568,
#    'original_language': 'en',
#    'original_title': 'Unhinged',
#    'overview': 'A divorced mother honks impatiently at a deranged middle-aged stranger at a red light while running late on her way to work. His road rage escalates to horrifyingly psychotic proportions as he becomes single-mindedly determined to teach her a deadly lesson for provoking him.',
#    'poster_path': '/6WC3cIhuaLZSq3SbtdOp2ZTSTe.jpg',
#    'release_date': '2020-07-02',
#    'title': 'Unhinged',
#    'video': False,
#    'vote_average': 6.5,
#    'vote_count': 355,
#    'popularity': 91.973,
#    'media_type': 'movie'},
#   {'id': 560050,
#    'video': False,
#    'vote_count': 341,
#    'vote_average': 7.7,
#    'title': 'Over the Moon',
#    'release_date': '2020-10-16',
#    'original_language': 'en',
#    'original_title': 'Over the Moon',
#    'genre_ids': [16, 12, 10751, 14],
#    'backdrop_path': '/htBUhLSS7FfHtydgYxUWjL3J1Q1.jpg',
#    'adult': False,
#    'overview': 'A girl builds a rocket to travel to the moon in hopes of meeting the legendary Moon Goddess.',
#    'poster_path': '/lQfdytwN7eh0tXWjIiMceFdBBvD.jpg',
#    'popularity': 928.622,
#    'media_type': 'movie'},
#   {'id': 671039,
#    'video': False,
#    'vote_count': 135,
#    'vote_average': 6.4,
#    'title': 'Rogue City',
#    'release_date': '2020-10-30',
#    'original_language': 'fr',
#    'original_title': 'Bronx',
#    'genre_ids': [53, 28, 18, 80],
#    'backdrop_path': '/gnf4Cb2rms69QbCnGFJyqwBWsxv.jpg',
#    'adult': False,
#    'overview': 'Caught in the crosshairs of police corruption and Marseille’s warring gangs, a loyal cop must protect his squad by taking matters into his own hands.',
#    'poster_path': '/9HT9982bzgN5on1sLRmc1GMn6ZC.jpg',
#    'popularity': 827.606,
#    'media_type': 'movie'},
#   {'id': 575774,
#    'video': False,
#    'vote_count': 158,
#    'vote_average': 6.5,
#    'title': 'His House',
#    'release_date': '2020-01-27',
#    'original_language': 'en',
#    'original_title': 'His House',
#    'genre_ids': [18, 27, 53],
#    'backdrop_path': '/6aVB2B2GDc4EuNinHgoBgtkuHQz.jpg',
#    'adult': False,
#    'overview': 'After making a harrowing escape from war-torn South Sudan, a young refugee couple struggle to adjust to their new life in a small English town that has an unspeakable evil lurking beneath the surface.',
#    'poster_path': '/s6XxJEe4ovVTMgmGmKeO87OFANU.jpg',
#    'popularity': 420.34,
#    'media_type': 'movie'},
#   {'id': 590995,
#    'video': False,
#    'vote_count': 89,
#    'vote_average': 6.5,
#    'title': 'The Craft: Legacy',
#    'release_date': '2020-10-28',
#    'original_language': 'en',
#    'original_title': 'The Craft: Legacy',
#    'genre_ids': [27, 18, 14],
#    'backdrop_path': '/lIE7kfdLBRd0KENNtOaIqPPWNqh.jpg',
#    'adult': False,
#    'overview': 'An eclectic foursome of aspiring teenage witches get more than they bargained for as they lean into their newfound powers.',
#    'poster_path': '/lhMIra0pqWNuD6CIXoTmGwZ0EBS.jpg',
#    'popularity': 111.185,
#    'media_type': 'movie'},
#   {'id': 613504,
#    'video': False,
#    'vote_count': 1620,
#    'vote_average': 7.4,
#    'title': 'After We Collided',
#    'release_date': '2020-09-02',
#    'original_language': 'en',
#    'original_title': 'After We Collided',
#    'genre_ids': [10749, 18],
#    'backdrop_path': '/6hgItrYQEG33y0I7yP2SRl2ei4w.jpg',
#    'adult': False,
#    'overview': 'Tessa finds herself struggling with her complicated relationship with Hardin; she faces a dilemma that could change their lives forever.',
#    'poster_path': '/kiX7UYfOpYrMFSAGbI6j1pFkLzQ.jpg',
#    'popularity': 551.934,
#    'media_type': 'movie'},
#   {'id': 590223,
#    'video': False,
#    'vote_count': 312,
#    'vote_average': 7.6,
#    'title': 'Love and Monsters',
#    'release_date': '2020-10-16',
#    'original_language': 'en',
#    'original_title': 'Love and Monsters',
#    'genre_ids': [28, 12, 35, 878],
#    'backdrop_path': '/lA5fOBqTOQBQ1s9lEYYPmNXoYLi.jpg',
#    'adult': False,
#    'overview': 'Seven years after the Monsterpocalypse, Joel Dawson, along with the rest of humanity, has been living underground ever since giant creatures took control of the land. After reconnecting over radio with his high school girlfriend Aimee, who is now 80 miles away at a coastal colony, Joel begins to fall for her again. As Joel realizes that there’s nothing left for him underground, he decides against all logic to venture out to Aimee, despite all the dangerous monsters that stand in his way.',
#    'poster_path': '/r4Lm1XKP0VsTgHX4LG4syAwYA2I.jpg',
#    'popularity': 476.381,
#    'media_type': 'movie'},
#   {'id': 738646,
#    'video': False,
#    'vote_count': 86,
#    'vote_average': 7.0,
#    'title': 'Operation Christmas Drop',
#    'release_date': '2020-11-05',
#    'original_language': 'en',
#    'original_title': 'Operation Christmas Drop',
#    'genre_ids': [35, 10751, 10749],
#    'backdrop_path': '/q9ZLjqti3UTt5ZC3qQMZhRNueGc.jpg',
#    'adult': False,
#    'overview': 'While gathering evidence to support closing a tropical U.S. Air Force base, a congressional aide warms to its generous captain.',
#    'poster_path': '/1fUcKFDy58DhWYd5Y7Nu5DgpxaE.jpg',
#    'popularity': 220.335,
#    'media_type': 'movie'},
#   {'id': 575417,
#    'video': False,
#    'vote_count': 127,
#    'vote_average': 6.2,
#    'title': 'On the Rocks',
#    'release_date': '2020-10-02',
#    'original_language': 'en',
#    'original_title': 'On the Rocks',
#    'genre_ids': [18, 35],
#    'backdrop_path': '/sLCsss7LjBeeRgJwpiOuLdtHUBa.jpg',
#    'adult': False,
#    'overview': 'Faced with sudden doubts about her marriage, a young New York mother teams up with her larger-than-life playboy father to tail her husband.',
#    'poster_path': '/fcijRCmB7yTtloh4Pumy9b1rkwU.jpg',
#    'popularity': 123.729,
#    'media_type': 'movie'},
#   {'id': 505379,
#    'video': False,
#    'vote_count': 354,
#    'vote_average': 6.4,
#    'title': 'Rebecca',
#    'release_date': '2020-10-16',
#    'original_language': 'en',
#    'original_title': 'Rebecca',
#    'genre_ids': [10749, 18, 9648, 53],
#    'backdrop_path': '/AuL2hsPrdGOungMIxTuXGXgmxKZ.jpg',
#    'adult': False,
#    'overview': "After a whirlwind romance with a wealthy widower, a naïve bride moves to his family estate but can't escape the haunting shadow of his late wife.",
#    'poster_path': '/bSKVKcCXdKxkbgf0LL8lBTPG02e.jpg',
#    'popularity': 181.465,
#    'media_type': 'movie'},
#   {'id': 556984,
#    'video': False,
#    'vote_count': 513,
#    'vote_average': 7.8,
#    'title': 'The Trial of the Chicago 7',
#    'release_date': '2020-09-25',
#    'original_language': 'en',
#    'original_title': 'The Trial of the Chicago 7',
#    'genre_ids': [18, 36, 53],
#    'backdrop_path': '/v8Nf6Y1qL1Q3PWTBezXNPPaXqza.jpg',
#    'adult': False,
#    'overview': 'What was intended to be a peaceful protest at the 1968 Democratic National Convention turned into a violent clash with police and the National Guard. The organizers of the protest — including Abbie Hoffman, Jerry Rubin, Tom Hayden and Bobby Seale — were charged with conspiracy to incite a riot and the trial that followed was one of the most notorious in history.',
#    'poster_path': '/ahf5cVdooMAlDRiJOZQNuLqa1Is.jpg',
#    'popularity': 143.523,
#    'media_type': 'movie'},
#   {'id': 435615,
#    'video': False,
#    'vote_count': 38,
#    'vote_average': 6.8,
#    'title': 'Possessor Uncut',
#    'release_date': '2020-10-02',
#    'original_language': 'en',
#    'original_title': 'Possessor Uncut',
#    'genre_ids': [53, 878, 27],
#    'backdrop_path': '/1DWIdrj8Qga8N3JaDYjJ8z59k2F.jpg',
#    'adult': False,
#    'overview': 'Tasya Vos, an elite corporate assassin, uses brain-implant technology to take control of other people’s bodies to terminate high-profile targets. As she sinks deeper into her latest assignment, Vos becomes trapped inside a mind that threatens to obliterate her.',
#    'poster_path': '/oLQlUUSlI669r1bgQ7AlnjcrrvC.jpg',
#    'popularity': 62.628,
#    'media_type': 'movie'},
#   {'id': 299534,
#    'video': False,
#    'vote_count': 15589,
#    'vote_average': 8.3,
#    'title': 'Avengers: Endgame',
#    'release_date': '2019-04-24',
#    'original_language': 'en',
#    'original_title': 'Avengers: Endgame',
#    'genre_ids': [12, 878, 28],
#    'backdrop_path': '/orjiB3oUIsyz60hoEqkiGpy5CeO.jpg',
#    'adult': False,
#    'overview': "After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.",
#    'poster_path': '/or06FN3Dka5tukK1e9sl16pB3iy.jpg',
#    'popularity': 193.659,
#    'media_type': 'movie'},
#   {'id': 627290,
#    'video': False,
#    'vote_count': 230,
#    'vote_average': 6.0,
#    'title': 'Antebellum',
#    'release_date': '2020-09-02',
#    'original_language': 'en',
#    'original_title': 'Antebellum',
#    'genre_ids': [27],
#    'backdrop_path': '/pGqBDYycGWsMYc57sYv5M9GAQoW.jpg',
#    'adult': False,
#    'overview': "Successful author Veronica finds herself trapped in a horrifying reality and must uncover the mind-bending mystery before it's too late.",
#    'poster_path': '/irkse1FMm9dWemwlxKJ7RINT9Iy.jpg',
#    'popularity': 117.055,
#    'media_type': 'movie'}],
#  'total_pages': 1000,
#  'total_results': 20000}

# %%
trend_movie_week = resp.text
trend_movie_week = json.loads(trend_movie_week)

# %%
for key in trend_movie_week.keys():
    print(key)
# Out:
# page
# results
# total_pages
# total_results

# %%
trend_movie_week['results'][0]
# Out:
# {'id': 400160,
#  'video': False,
#  'vote_count': 1046,
#  'vote_average': 8.3,
#  'title': 'The SpongeBob Movie: Sponge on the Run',
#  'release_date': '2020-08-14',
#  'original_language': 'en',
#  'original_title': 'The SpongeBob Movie: Sponge on the Run',
#  'genre_ids': [14, 16, 12, 35, 10751],
#  'backdrop_path': '/wu1uilmhM4TdluKi2ytfz8gidHf.jpg',
#  'adult': False,
#  'overview': 'When his best friend Gary is suddenly snatched away, SpongeBob takes Patrick on a madcap mission far beyond Bikini Bottom to save their pink-shelled pal.',
#  'poster_path': '/jlJ8nDhMhCYJuzOw3f52CP1W8MW.jpg',
#  'popularity': 1114.882,
#  'media_type': 'movie'}

# %%
import pandas as pd
trend_movie_week_df = pd.DataFrame(trend_movie_week['results'])

trend_movie_week_df.head()
