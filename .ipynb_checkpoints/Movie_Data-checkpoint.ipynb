# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("combined_movie_data.csv")

# %%
df.head()

# %%
df = df.drop(["Unnamed: 0"],axis=1, inplace=True)

# %%
df.head()
# Out:
#      titleId  start_year            genres  ordering  \
# 0  tt0069049      2018.0             Drama       3.0
# 1  tt0112502      2017.0   Horror,Thriller       3.0
# 2  tt4503112      2018.0     Action,Horror       3.0
# 3  tt9181914      2018.0  Animation,Family       5.0
# 4  tt0192528      2018.0             Drama       1.0
#
#                         title region      genre_ids    id_x  popularity  \
# 0  The Other Side of the Wind     US       [35, 18]  299782       9.800
# 1                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 2                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 3                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 4               Heaven & Hell     US           [18]  567662       0.600
#
#   release_date_x  vote_average  vote_count  id_y release_date_y  \
# 0     2018-11-02           7.0          64   NaN            NaN
# 1     2012-06-30           2.9          26   NaN            NaN
# ...

# %%
df['release_year'] = df['release_date_x'].str[:4]

# %%
df.head()
# Out:
#      titleId  start_year            genres  ordering  \
# 0  tt0069049      2018.0             Drama       3.0
# 1  tt0112502      2017.0   Horror,Thriller       3.0
# 2  tt4503112      2018.0     Action,Horror       3.0
# 3  tt9181914      2018.0  Animation,Family       5.0
# 4  tt0192528      2018.0             Drama       1.0
#
#                         title region      genre_ids    id_x  popularity  \
# 0  The Other Side of the Wind     US       [35, 18]  299782       9.800
# 1                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 2                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 3                     Bigfoot     US  [27, 878, 12]  117856       2.813
# 4               Heaven & Hell     US           [18]  567662       0.600
#
#   release_date_x  vote_average  vote_count  id_y release_date_y  \
# 0     2018-11-02           7.0          64   NaN            NaN
# 1     2012-06-30           2.9          26   NaN            NaN
# ...

# %% [raw]
# # df = df.drop(["star_year"],axis=1, inplace=True)
# df['years'] = np.where(df['original_title'] == tmdb['title'], tmdb['title'],"different")
